# %% [markdown]
# Question 1: What is Simple Linear Regression (SLR)? Explain its purpose.
#
# **Answer:**
# Simple Linear Regression (SLR) is a statistical method used to model the relationship between two variables: a single independent variable (predictor) and a single dependent variable (target). It assumes that there is a linear relationship between these two variables, meaning the data points can be approximated by a straight line.
#
# **Purpose:** The primary purpose of SLR is to predict the value of the dependent variable based on the value of the independent variable and to understand the nature of the relationship (positive or negative correlation) between them.

# %% [markdown]
# Question 2: What are the key assumptions of Simple Linear Regression?
#
# **Answer:**
# The four key assumptions of Simple Linear Regression are:
#
# 1. Linearity: The relationship between the independent and dependent variables is linear.
# 2. Independence: The observations are independent of each other (residuals should not be correlated).
# 3. Homoscedasticity: The variance of the residuals (errors) is constant across all levels of the independent variable.
# 4. Normality: The residuals of the model are normally distributed.

# %% [markdown]
# Question 3: Write the mathematical equation for a simple linear regression model and explain each term.
#
# **Answer:**
# Answer: The equation is: y=β0​+β1​x+ϵ
#
# y: The dependent variable (target value).
#
# x: The independent variable (predictor value).
#
# β0​: The y-intercept (the value of y when x=0).
#
# β1​: The slope coefficient (indicates how much y changes for a one-unit change in x).
#
# ϵ: The error term (residual), representing the difference between the actual observed value and the value predicted by the model.

# %% [markdown]
# Question 4: Provide a real-world example where simple linear regression can be applied.
#
# **Answer:**
# Example: Predicting Salary based on Years of Experience.
# A company wants to predict the salary of a new employee based on their years of professional experience. By collecting historical data on current employees, a simple linear regression model can be fitted to estimate the expected salary for a candidate with a specific number of years of experience.

# %% [markdown]
# Question 5: What is the method of least squares in linear regression?
#
# **Answer:**
# The method of least squares (Ordinary Least Squares or OLS) is an optimization technique used to find the best-fitting line for the data. It works by minimizing the sum of the squared vertical differences (residuals) between the observed data points and the values predicted by the linear approximation. By minimizing this sum of squared errors, the method determines the optimal values for the intercept and slope.

# %% [markdown]
# Question 6: What is Logistic Regression? How does it differ from Linear Regression?
#
# **Answer:**
# Logistic Regression is a supervised learning algorithm used for classification problems. It predicts the probability that an instance belongs to a specific class (e.g., Yes/No, True/False) using a logistic function (sigmoid curve) to map predictions between 0 and 1.
#
# **Difference:**
#
# * Linear Regression is used for regression tasks to predict a continuous numerical value (e.g., price, temperature).
# * Logistic Regression is used for classification tasks to predict a categorical outcome or probability (e.g., spam vs. not spam).

# %% [markdown]
# Question 7: Name and briefly describe three common evaluation metrics for regression models.
#
# **Answer:**
#
# 1. Mean Absolute Error (MAE): The average of the absolute differences between predicted and actual values. It measures the average magnitude of errors.
# 2. Mean Squared Error (MSE): The average of the squared differences between predicted and actual values. It penalizes larger errors more heavily than MAE.
# 3. Root Mean Squared Error (RMSE): The square root of the MSE. It brings the error metric back to the same unit as the target variable, making it easier to interpret.

# %% [markdown]
# Question 8: What is the purpose of the R-squared metric in regression analysis?
#
# **Answer:**
# R-squared (R^2), also known as the Coefficient of Determination, measures the proportion of the variance in the dependent variable that is predictable from the independent variable(s). It ranges from 0 to 1. An R^2 of 1 indicates the model perfectly explains the variability of the target data, while 0 indicates it explains none of the variability. It is essentially a measure of "goodness of fit."

# %% [markdown]
# Question 9: Write Python code to fit a simple linear regression model using scikit-learn and print the slope and intercept.

# %%
#Answer:

import numpy as np
from sklearn.linear_model import LinearRegression

X = np.array([[1], [2], [3], [4], [5]]) 
y = np.array([2, 4, 5, 4, 5])    
model = LinearRegression()

model.fit(X, y)

print(f"Slope (Coefficient): {model.coef_[0]}")
print(f"Intercept: {model.intercept_}")
# Out:
# Slope (Coefficient): 0.6000000000000002
# Intercept: 2.1999999999999993

# %% [markdown]
# Question 10: How do you interpret the coefficients in a simple linear regression model?
#
# **Answer:**
#
# * Intercept: This represents the baseline value of the dependent variable  when the independent variable  is zero. In many real-world contexts, this might be a theoretical baseline rather than a practically observing value.
# * Slope: This represents the rate of change. It tells you how much the dependent variable  is expected to increase (or decrease, if negative) for every single-unit increase in the independent variable .
